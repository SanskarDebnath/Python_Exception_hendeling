# %%
a = input ("enter a value")
b = input ("enter a value")
try:
    c = a/b
    print (C)
except TypeError:
    print ("operation not allowed")
# Out:
# enter a value4
# enter a value5
# operation not allowed

# %%
"""
a= 10
b = 0
c = a / b
print(c)
"""

# raising exception manually

# raise Exception
# ---custom exception
# raise Exception('CPU overloaded')

"""
# Ex 1
x = input('Enter a value : ')
y = input('Enter a value : ')

try:
    z = x / y
    print('Result = ',z)
except TypeError:
    print('Operation not allowed on data type ', type(x), ' and ', type(y))

"""

#ex 2
"""
x = input('Enter a value : ')
y = input('Enter a value : ')

try:
    z = float(x) / float(y)
    print('Result = ',z)
except ValueError:  #  if x or y is a plain string like 'sky'
    print('Conversion failed')


    i/: x = 50 y = 10 -> ok     x = 40 y = 'Sky' -> ValueError
"""
#ex 3 : multi catch
"""
x = input('Enter a value : ')
y = input('Enter a value : ')
try:
    z = float(x) / float(y)
    print('Result = ',z)
except ZeroDivisionError as ex:  #  ex is the exception object
    print('y can not be 0')
    print(ex)
except ValueError as ve:
    print(ve)
"""
# Alternate multicatch
"""
x = input('Enter a value : ')
y = input('Enter a value : ')
try:
    z = float(x) / float(y)
    print('Result = ',z)
except (ZeroDivisionError, ValueError)  as ex:  #  ex is the exception object
    print(ex)
"""

# Generic exception
#ex a
"""
l = [10,20,50,60, 9]

try:
    l[6] = 47
except:  # no exception class specified -> generic exception
    print('Something went wrong !!')
"""
    
#ex b
"""
l = [10,20,50,60, 9]
x = input('Enter value ')
try:
    l[6] = 47
    x = x  / 10
except Exception as ex: 
    print(ex)
"""
"""
l = [10,20,50,60, 9]
x = input('Enter value ')
try:
    x =  50 / float(x)
    print('x=', x)
    l[6] = 47
except ValueError as te:
    print(te)
except Exception as ex: 
    print(ex)
"""


# scanf("%d %d %f", &a, &b , &c)
"""
a, b = input('Enter two values ').split() ==> '20 30'.split()
print('1st value  = ', a)
print('2nd value = ', b)

c = float(a)/ float(b)
print(c)
"""
# handling exception from other function
#ex a
"""
def operation(a, b):
    r = a / b
    print('r = ', r)

m, n = input('Enter two values ').split()  # will raise ValueError if only 1 input is given
try:
    operation(float(m), float(n))
except Exception as ex:
    print(ex)
"""
# ex b
"""
def operation(a, b):
    try:
        r = a / b
        print('r = ', r)
    except ZeroDivisionError:
        print('Can not devided by 0')
    
try:
    m, n = input('Enter two values ').split()  # will raise ValueError if only 1 input is given
    operation(float(m), float(n))
except (TypeError, ValueError) as ex:
    print(ex)
"""

# ex c : Nested exception
"""
def operation(a, b):
    r = a / b
    print('r = ', r)

try:
    m, n = input('Enter two values ').split()  # will raise ValueError if only 1 input is given
    try:
        operation(float(m), float(n))
    except ZeroDivisionError as ex:
        print(ex)
except ValueError as ve:
    print('Value error : ', ve)
except Exception as e:
    print('Something went wrong !!')
"""

# Rethrow exception

def operation():
    try:
        a, b = input('Enter two values ').split() 
    except ValueError:
        raise  # Re-throw

    try:
        r = float(a) / float(b)
        print('r = ', r)
    except ZeroDivisionError:
        raise # Re-throw
    
try:
    operation()
except Exception as ex:
    print(ex)

# %%
x = input('Enter a value : ')
y = input('Enter a value : ')
try:
    z = float(x) / float(y)
    print('Result = ',z)
except ZeroDivisionError as ex:  #  ex is the exception object
    print('y can not be 0')
    print(ex)
except ValueError as ve:
    print(ve)
# Out:
# Enter a value : 44
# Enter a value : 5555555555
# Result =  7.920000000792e-09

# %%
l = [10,20,50,60, 9]
x = input('Enter value ')
try:
    l[6] = 47
    x = x  / 10
except Exception as ex: 
    print(ex)
"""
"""
l = [10,20,50,60, 9]
x = input('Enter value ')
try:
    x =  50 / float(x)
    print('x=', x)
    l[6] = 47
except ValueError as te:
    print(te)
except Exception as ex: 
    print(ex)
